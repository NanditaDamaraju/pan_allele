# %%
import os
import sys
import pepdata
sys.path.append(os.path.split(os.getcwd())[0])
import pandas as pd
import numpy as np

# %%
from pan_allele.helpers.pan_allele_data_helpers import *
# Out:
# Couldn't import dot_parser, loading of dot files will not be possible.

# %%
df = pepdata.iedb.mhc.load_dataframe(mhc_class=2, )

# %%
list(df.columns)
# Out:
# [(u'Reference', u'MHC ligand ID'),
#  (u'Reference', u'Reference ID'),
#  (u'Reference', u'Type'),
#  (u'Reference', u'PubMed ID'),
#  (u'Reference', u'Authors'),
#  (u'Reference', u'Journal'),
#  (u'Reference', u'Date'),
#  (u'Reference', u'Title'),
#  (u'Reference', u'Submission ID'),
#  (u'Epitope', u'Epitope ID'),
#  (u'Epitope', u'Object Type'),
#  (u'Epitope', u'Description'),
#  (u'Epitope', u'Starting Position'),
#  (u'Epitope', u'Ending Position'),
#  (u'Epitope', u'Non-peptidic epitope ChEBI ID'),
#  (u'Epitope', u'Antigen Name'),
#  (u'Epitope', u'Antigen ID'),
#  (u'Epitope', u'Organism Name'),
#  (u'Epitope', u'Organism ID'),
#  (u'Epitope', u'Epitope Comments'),
#  (u'Epitope', u'Related Object Type'),
#  (u'Host', u'Name'),
#  (u'Host', u'Host ID'),
#  (u'Host', u'Geolocation'),
#  (u'In vivo Process', u'Process Type'),
#  (u'In vivo Process', u'Disease State'),
#  (u'In vivo Process', u'Disease Code'),
#  (u'In vivo Process', u'Disease Stage'),
#  (u'In vivo Process', u'Processed Antigen Epitope Relation'),
#  (u'In vivo Process', u'Processed Antigen Object Type'),
#  (u'In vivo Process', u'Processed Antigen Description'),
#  (u'In vivo Process', u'Processed Antigen Ending Position'),
#  (u'In vivo Process', u'Non-peptidic Processed Antigen ChEBI ID'),
#  (u'In vivo Process', u'Processed Antigen Source Molecule Name'),
#  (u'In vivo Process', u'Processed Antigen Source Molecule ID'),
#  (u'In vivo Process', u'Processed Antigen Organism Name'),
#  (u'In vivo Process', u'Processed Antigen Organism ID'),
#  (u'In vitro Process', u'In vitro administration type'),
#  (u'In vitro Process', u'Processed Antigen Epitope Relation'),
#  (u'In vitro Process', u'Processed Antigen Object Type'),
#  (u'In vitro Process', u'Processed Antigen Description'),
#  (u'In vitro Process', u'Processed Antigen Starting Position'),
#  (u'In vitro Process', u'Processed Antigen Ending Position'),
#  (u'In vitro Process', u'Processed Antigen Source Molecule Name'),
#  (u'In vitro Process', u'Processed Antigen Source Molecule ID'),
#  (u'In vitro Process', u'Processed Antigen Organism Name'),
#  (u'In vitro Process', u'Processed Antigen Organism ID'),
#  (u'Processed Antigen Comments', u'Processed Antigen Comments'),
#  (u'Assay', u'Method/Technique'),
#  (u'Assay', u'Assay Group'),
#  (u'Assay', u'Units'),
#  (u'Assay', u'Assay Type ID'),
#  (u'Assay', u'Qualitative Measure'),
#  (u'Assay', u'Quantitative measurement'),
#  (u'Assay', u'Number of Subjects Tested'),
#  (u'Assay', u'Number of Subjects Responded'),
#  (u'Assay', u'Response Frequency'),
#  (u'Assay', u'3D complex ID'),
#  (u'Antigen Processing Cells', u'Cell Tissue Type'),
#  (u'Antigen Processing Cells', u'Cell Type'),
#  (u'Antigen Processing Cells', u'Cell Culture Conditions'),
#  (u'MHC', u'Allele Name'),
#  (u'MHC', u'MHC Allele ID'),
#  (u'MHC', u'MHC allele class'),
#  (u'Assay Comments', u'Assay Comments')]

# %% [markdown]
# #Write dataframe to Data file

# %% [markdown]
# ####with species, mhc_allele, peptide_length, cv, seuquence, inequality, and binding strength

# %%
def get_file_from_df(df):
    new_df = pd.DataFrame(columns=('species','mhc','peptide_length','cv','sequence','inequality','meas'))
    new_df['peptide_length'] = df.Epitope.Description.str.len()
    new_df['mhc'] = df.MHC['Allele Name']
    new_df['species'] = "human"
    new_df['sequence'] = df.Epitope['Description']
    new_df['meas'] = df.Assay['Quantitative measurement']
    new_df['cv']="TDB"
    new_df['inequality']="="
    new_df = new_df.dropna()
    
    return new_df

# %%
df_date = df[df.Reference.Date < 2011]
new_df = get_file_from_df(df_date)
new_df.to_csv('bdata.classii.2015.csv', sep='\t', nanRep=None, index=False)
new_df
# Out:
#        species             mhc  peptide_length   cv                sequence  \
# 71       human         HLA-DR1              14  TDB          SEFAYGSFVRTVSL
# 72       human        HLA-DR15              14  TDB          SEFAYGSFVRTVSL
# 73       human        HLA-DR11              14  TDB          SEFAYGSFVRTVSL
# 74       human        HLA-DR13              14  TDB          SEFAYGSFVRTVSL
# 75       human         HLA-DR7              14  TDB          SEFAYGSFVRTVSL
# 160      human  HLA-DRB1*15:01              15  TDB         EKAKYEAYKAAAAAA
# 161      human  HLA-DRB1*15:01              15  TDB         EKPKYEAYKAAAAPA
# 162      human  HLA-DRB1*15:01              15  TDB         EKPKFEAYKAAAAPA
# 163      human  HLA-DRB1*15:01              15  TDB         EKAKEEAYKAAAAAA
# 164      human  HLA-DRB1*15:01              15  TDB         EKPKEEAFKAAAAPA
# 165      human  HLA-DRB1*15:01              15  TDB         EKAKFEAFKAAAAAA
# 166      human  HLA-DRB1*15:01              15  TDB         EKPKVEAYKAAAAPA
# 167      human  HLA-DRB1*15:01              17  TDB       APEKAKFEAFKAAAAPA
# 168      human  HLA-DRB1*15:01              17  TDB       APEKAKFEAYKAAAAPA
# 169      human  HLA-DRB1*15:01              17  TDB       APEKAKVEAFKAAAAPA
# 170      human  HLA-DRB1*15:01              15  TDB         EAKKYEAYKAAAAAA
# 171      human  HLA-DRB1*15:01              15  TDB         EAPKFEAYKAAAAPA
# 172      human  HLA-DRB1*15:01              15  TDB         EAPKVEAYKAAAAPA
# 173      human  HLA-DRB1*15:01              15  TDB         EAPKFEAFKAAAAPA
# 174      human  HLA-DRB1*15:01              17  TDB       APEAKKFEAFKAAAAPA
# 175      human  HLA-DRB1*15:01              17  TDB       APEAKKFEAYKAAAAPA
# 176      human  HLA-DRB1*15:01              17  TDB       APEAKKVEAFKAAAAPA
# 177      human  HLA-DRB1*15:01              15  TDB         ENPVVHFFKNIVTPR
# 178      human  HLA-DRB1*15:01              21  TDB   MEVGWYRSPFSRVVHLYRNGK
# 179      human  HLA-DRB1*15:01              21  TDB   MEVGWYRPPFSRVVHLYRNGK
# 180      human  HLA-DRB1*03:01              20  TDB    KSKKHMDLDGEMMMAKKLKD
# 181      human  HLA-DRB1*03:01              20  TDB    KSKKHMIHDIEKMKIKKLKD
# 182      human  HLA-DRB1*01:01              20  TDB    KSKKHMDLDGEMMMAKKLKD
# 183      human  HLA-DRB1*04:01              20  TDB    KSKKHMDLDGEMMMAKKLKD
# 184      human  HLA-DRB1*11:01              20  TDB    KSKKHMDLDGEMMMAKKLKD
# ...        ...             ...             ...  ...                     ...
# 325686   human  HLA-DRB1*15:01              20  TDB    HGRGTCNYYSNSYSFWLASL
# 325687   human  HLA-DRB5*01:01              20  TDB    TTAIPSCPEGTVPLYSGFSF
# 325688   human  HLA-DRB5*01:01              20  TDB    QGNQRAHGQDLGTLGSCLQR
# 325689   human  HLA-DRB5*01:01              20  TDB    LGTLGSCLQRFTTMPFLFCN
# 325690   human  HLA-DRB5*01:01              20  TDB    RCTVCEGPAIAIAVHSQTTD
# 325691   human  HLA-DRB5*01:01              20  TDB    IPPCPHGWISLWKGFSFIMF
# 325692   human  HLA-DRB5*01:01              20  TDB    EFRASPFLECHGRGTCNYYS
# 325693   human  HLA-DRB5*01:01              20  TDB    NPERMFRKPIPSTVKAGELE
# 325694   human  HLA-DRB1*15:01              22  TDB  GTVPLYSGFSFLFVQGNQRAHG
# 325695   human  HLA-DRB1*15:01              20  TDB    LYSGFSFLFVQGNQRAHGQD
# 325696   human  HLA-DRB1*15:01              20  TDB    LGTLGSCLQRFTTMPFLFCN
# 325697   human  HLA-DRB1*15:01              20  TDB    FTTMPFLFCNVNDVCNFASR
# 325698   human  HLA-DRB1*15:01              21  TDB   VNDVCNFASRNDYSYWLSTPA
# 325699   human  HLA-DRB1*15:01              20  TDB    NDYSYWLSTPALMPMNMAPI
# 325700   human  HLA-DRB1*15:01              20  TDB    ALMPMNMAPITGRALEPYIS
# 325701   human  HLA-DRB1*15:01              20  TDB    RCTVCEGPAIAIAVHSQTTD
# 325702   human  HLA-DRB1*15:01              20  TDB    ALASPGSCLEEFRASPFLEC
# 325703   human  HLA-DRB1*15:01              20  TDB    EFRASPFLECHGRGTCNYYS
# 325704   human  HLA-DRB1*15:01              20  TDB    NSYSFWLASLNPERMFRKPI
# 325705   human  HLA-DRB1*15:01              20  TDB    PSTVKAGELEKIISRCQVCM
# 325706   human  HLA-DRB5*01:01              20  TDB    TGRALEPYISRCTVCEGPAI
# 325707   human  HLA-DRB5*01:01              20  TDB    ALASPGSCLEEFRASPFLEC
# 325708   human  HLA-DRB5*01:01              20  TDB    PSTVKAGELEKIISRCQVCM
# 325709   human  HLA-DRB1*15:01              20  TDB    TTAIPSCPEGTVPLYSGFSF
# 325710   human  HLA-DRB1*15:01              20  TDB    QGNQRAHGQDLGTLGSCLQR
# 325711   human  HLA-DRB1*15:01              20  TDB    NPERMFRKPIPSTVKAGELE
# 326041   human  HLA-DRB5*01:01              16  TDB        PFLFCNVNDVCNFASR
# 326042   human  HLA-DRB1*15:01              16  TDB        PFLFCNVNDVCNFASR
# 326043   human  HLA-DRB1*15:01              19  TDB     ALASPGSCLEEFRASPFLE
# 326044   human  HLA-DRB5*01:01              19  TDB     ALASPGSCLEEFRASPFLE
#
#        inequality    meas
# 71              =    4600
# 72              =    7100
# 73              =    5100
# 74              =    2000
# 75              =    6100
# 160             =      18
# 161             =      14
# 162             =      26
# 163             =       0
# 164             =       0
# 165             =      19
# 166             =      41
# 167             =      34
# 168             =      31
# 169             =       5
# 170             =       0
# 171             =      13
# 172             =      44
# 173             =      15
# 174             =      26
# 175             =      14
# 176             =      23
# 177             =      15
# 178             =    1600
# 179             =   13500
# 180             =      53
# 181             =      25
# 182             =       0
# 183             =      34
# 184             =      31
# ...           ...     ...
# 325686          =    1000
# 325687          =    1000
# 325688          =    1000
# 325689          =    1000
# 325690          =    1000
# 325691          =    1000
# 325692          =    1000
# 325693          =    1000
# 325694          =    1000
# 325695          =    1000
# 325696          =    1000
# 325697          =    1700
# 325698          =    1000
# 325699          =    1000
# 325700          =    1000
# 325701          =    1000
# 325702          =   12000
# 325703          =    1000
# 325704          =    1000
# 325705          =    1000
# 325706          =  100000
# 325707          =  100000
# 325708          =  100000
# 325709          =  100000
# 325710          =  100000
# 325711          =  100000
# 326041          =    9000
# 326042          =    6000
# 326043          =    1500
# 326044          =  100000
#
# [44707 rows x 7 columns]

# %%
new_df.mhc.value_counts()
# Out:
# HLA-DRB1*01:01                          7300
# HLA-DRB1*04:01                          2555
# HLA-DRB1*15:01                          2142
# HLA-DRB1*03:01                          2128
# HLA-DRB1*11:01                          2076
# HLA-DRB5*01:01                          2055
# HLA-DRB1*07:01                          1975
# HLA-DRB4*01:01                          1668
# HLA-DRB1*13:02                          1660
# HLA-DRB1*04:05                          1630
# HLA-DRB1*08:02                          1516
# HLA-DRB3*01:01                          1507
# HLA-DRB1*09:01                          1442
# HLA-DQA1*05:01/DQB1*02:01                969
# HLA-DRB1*04:04                           929
# HLA-DQA1*03:01/DQB1*03:02                867
# HLA-DRB1*12:01                           769
# HLA-DQA1*01:02/DQB1*06:02                733
# HLA-DPA1*01:03/DPB1*02:01                712
# HLA-DQA1*05:01/DQB1*03:01                712
# HLA-DPA1*01:03/DPB1*04:01                699
# HLA-DQA1*01:01/DQB1*05:01                687
# HLA-DPA1*03:01/DPB1*04:02                687
# HLA-DRB3*02:02                           687
# HLA-DPA1*02:01/DPB1*01:01                687
# HLA-DQA1*04:01/DQB1*04:02                687
# HLA-DPA1*02:01/DPB1*05:01                687
# HLA-DR1                                  578
# HLA-DR3                                  457
# HLA-DR4                                  383
#                                         ...
# HLA-DR6                                   17
# HLA-DRB5*01:02                            16
# HLA-DRB1*16:01                            16
# HLA-DRB3*03:01                            16
# HLA-DQA1*02:01/DQB1*02:01                 15
# HLA-DRB1*04:06                            14
# HLA-DRA*01:01/DRB1*15:01                  13
# HLA-DRB1*03:05                            13
# HLA-DR53                                  12
# HLA-DRB1*11:03                            12
# HLA-DRB1*11:02                            12
# HLA-DRB1*13:04                            11
# HLA-DRB1*13:03                            11
# HLA-DR52                                  10
# HLA-DQA1*02:01/DQB1*02:02                  8
# HLA-DRB1*08:03                             7
# HLA-DRB1*15:02                             6
# HLA-DRA*01:01/DRB1*08:01                   5
# HLA-DPB1*05:01                             5
# HLA-DPw2                                   5
# HLA-DRA*01:01/DRB5*01:01                   4
# HLA-DRA*01:01/DRB1*04:04                   3
# HLA-DQB1*06:02                             2
# HLA-DQ                                     2
# HLA-DQB1*05:01                             2
# HLA-DRA*01:01/DRB1*01:01 G86Y mutant       2
# HLA-DQB1*02:01                             2
# HLA-DRB1*16:02                             1
# HLA-DRB1*14:02                             1
# HLA-DRB1*13:05                             1
# dtype: int64

# %%
new_df.peptide_length.value_counts()
# Out:
# 15    66350
# 20     4426
# 16     2341
# 17     2254
# 13     1279
# 18     1037
# 21      799
# 14      708
# 12      703
# 11      403
# 19      365
# 10      181
# 24      155
# 22      137
# 23      119
# 9       108
# 26       86
# 31       82
# 25       74
# 27       69
# 30       63
# 32       35
# 8        32
# 29       29
# 34       27
# 28       20
# 33       14
# 35       14
# 7        11
# 4         4
# 63        4
# 36        3
# 5         2
# 41        2
# 2         2
# 55        1
# 37        1
# 6         1
# dtype: int64
