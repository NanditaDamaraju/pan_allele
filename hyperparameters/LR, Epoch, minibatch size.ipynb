# %%
import matplotlib.pylab as plt
import seaborn as sns
import csv
import numpy as np
import pandas as pd
# %matplotlib inline

# %% [markdown]
# #Epoch

# %%
df = pd.DataFrame(columns = ('AUC', 'ACC', 'F1', 'precision', 'recall'))
with open('epoch/ffn_mult') as f:
    reader = csv.reader(f,delimiter = ',')
    for rows in reader:
        metrics = ([float(x.split(')')[0]) for x in rows[1:]])
        #print pd.Series(metrics)
        df = df.append(pd.Series(metrics,index=['AUC', 'ACC', 'F1', 'precision', 'recall']),ignore_index=True )
        #print AUC, ACC, F1, precision,recall
#plt.plot(AUC, np.arange(35))

# %%
df
# Out:
#          AUC       ACC        F1  precision    recall
# 0   0.572966  0.464423  0.466986   0.824324  0.325768
# 1   0.670218  0.646154  0.724138   0.825641  0.644860
# 2   0.619970  0.578846  0.652932   0.803119  0.550067
# 3   0.646713  0.600000  0.674491   0.814745  0.575434
# 4   0.661427  0.602885  0.667739   0.840081  0.554072
# 5   0.634693  0.577885  0.645109   0.817623  0.532710
# 6   0.647943  0.578846  0.647343   0.815416  0.536716
# 7   0.641056  0.601923  0.678571   0.810761  0.583445
# 8   0.644254  0.625962  0.705080   0.815789  0.620828
# 9   0.645351  0.605769  0.680685   0.816822  0.583445
# 10  0.662969  0.615385  0.690881   0.820183  0.596796
# 11  0.645966  0.614423  0.692720   0.812950  0.603471
# 12  0.667238  0.628846  0.701238   0.834254  0.604806
# 13  0.639455  0.612500  0.692131   0.808929  0.604806
# 14  0.667511  0.639423  0.712644   0.836331  0.620828
# 15  0.650118  0.594231  0.668239   0.812620  0.567423
# 16  0.664859  0.631731  0.705158   0.832727  0.611482
# 17  0.644417  0.615385  0.691358   0.819013  0.598131
# 18  0.654481  0.626923  0.703817   0.821747  0.615487
# 19  0.656383  0.603846  0.674566   0.825919  0.570093
# 20  0.666901  0.631731  0.708745   0.823322  0.622163
# 21  0.670814  0.628846  0.704441   0.825853  0.614152
# 22  0.658814  0.628846  0.705344   0.823529  0.616822
# 23  0.654366  0.619231  0.698630   0.812389  0.612817
# 24  0.656935  0.603846  0.673016   0.829746  0.566088
# 25  0.657628  0.624038  0.695720   0.833955  0.596796
# 26  0.667481  0.631731  0.708302   0.824468  0.620828
# 27  0.666258  0.625962  0.702372   0.822581  0.612817
# 28  0.670004  0.630769  0.705521   0.828829  0.614152
# 29  0.656621  0.614423  0.687938   0.824627  0.590120
# 30  0.667419  0.625962  0.702372   0.822581  0.612817
# 31  0.650384  0.633654  0.713318   0.817241  0.632844
# 32  0.660331  0.610577  0.681854   0.828244  0.579439
# 33  0.678245  0.648077  0.723565   0.833043  0.639519
# 34  0.659950  0.621154  0.700608   0.813051  0.615487
# 35  0.666830  0.620192  0.697781   0.817204  0.608812

# %%
df.plot()
